# %%
#Import the libraries

import tweepy #py lib for twitter API 
from tweepy import OAuthHandler  #authentication for twitter API
from tweepy import Stream
from tweepy.streaming import StreamListener
import json

# %%
#Credentials for accessing Twitter API
#Making it configurable - TBD;

consumer_key = ''
consumer_secret = ''
access_token = ''
access_secret = ''

# %%
class TweetsListener(StreamListener) :
    
    #Print twitter-stream to stdout
    def on_data(self, data):
        try:
            msg = json.loads(data)
            if msg['truncated'] is True:
                print(msg['extended_tweet']['full_text'])
            else:
                print(msg['text'])
            return True
        except BaseException as e:
            print("Error : %s" %str(e))
        return True
    
    #Deal with errors - printing on console 
    def on_error(self, status):
        print(status)
        return True

#With valid credentials, start a filtered stream
def sendData():
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)
    
    twitter_stream = Stream(auth, TweetsListener(), tweet_mode='extended')
    
    #Making filter string configurable - TBD;
    twitter_stream.filter(track=['trump'])

# %%
if __name__ == "__main__":
    
    #Generate Twitter Stream 
    sendData()

    #Send data to Kafka-topic ; TBD
# Out:
# As guerras de um presidente - O presidente dos EUA, Donald Trump, vem vendendo imagem de político austero, aquele que como mito consegue mudar... https://t.co/tAOwTasqWG
# RT @NumbersUSA: Labor market is tightening to the point that unemployed Americans are reentering the labor force and wages are starting to…
# RT @maggieNYT: Kelly again contradicted the president on his views of immigrants crossing the border illegally, saying they’re “overwhelmin…
# RT @marklevinshow: Another leftwing hack, creepy Jane Mayer, trashes Fox on CNN; CNN and it’s parade of fools are so concerned about object…
# RT @jimsciutto: Breaking: Trump admin has identified 471 parents who were removed from the US without their children and “without being giv…
# RT @realTylerZed: Kathy Griffin claims that Trump Supporters don't like her because she's a "self made woman."
#
# No, we don't like you becau…
# ...
